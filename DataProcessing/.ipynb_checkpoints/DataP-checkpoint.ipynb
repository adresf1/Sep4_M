# %%
from flask import Flask, jsonify, request
import psycopg2
import pandas as pd

app = Flask(__name__)

# Database configuration
DB_CONFIG = {
    "host": "b4miactrrxbtqyg0obdl-postgresql.services.clever-cloud.com",
    "port": "50013",
    "dbname": "b4miactrrxbtqyg0obdl",
    "user": "ujmpoinam3senrd9at7f",
    "password": "FZHjl5BLPSkZWlFJ6rXQqDfUK4Ekwz",
}

# Fetch sensor data (GET request)
@app.route('/fetch-sensor-data', methods=['GET'])
def fetch_sensor_data():
    try:
        # Connect to PostgreSQL
        conn = psycopg2.connect(**DB_CONFIG)
        
        # Use the correct table and column names
        query = "SELECT * FROM sensor_data;"  # Updated table name
        
        # Execute the query and read the result into a DataFrame
        df = pd.read_sql(query, conn)
        
        # Close the connection
        conn.close()

        # Convert to a list of dictionaries
        sensor_data = df.to_dict(orient="records")
        
        # Return the sensor data as a JSON response
        return jsonify(sensor_data), 200
    except Exception as e:
        # Error handling
        return jsonify({"error": f"Error retrieving sensor data: {str(e)}"}), 500


# Post sensor data (POST request)
@app.route('/fetch-sensor-data', methods=['POST'])
def post_sensor_data():
    try:
        # Receive sensor data from the .NET API
        sensor_data = request.get_json()

        # Validate the data (you can customize this to match your expected format)
        if not isinstance(sensor_data, list):
            return jsonify({"error": "Data should be a list of sensor readings"}), 400

        # Here, you can add logic to save the data to your database, log it, etc.
        # Example of inserting into the database (assuming the columns are temperature, humidity, etc.)
        conn = psycopg2.connect(**DB_CONFIG)
        cursor = conn.cursor()
        
        for sensor in sensor_data:
            query = """
                INSERT INTO sensor_data (temperature, humidity, co2, light, soil_moisture)
                VALUES (%s, %s, %s, %s, %s);
            """
            cursor.execute(query, (
                sensor.get('temperature', 0),
                sensor.get('humidity', 0),
                sensor.get('co2', 0),
                sensor.get('light', 0),
                sensor.get('soilMoisture', 0)
            ))

        # Commit the changes and close the connection
        conn.commit()
        conn.close()

        return jsonify({"status": "Data successfully received"}), 201
    except Exception as e:
        # Error handling
        return jsonify({"error": f"Error posting sensor data: {str(e)}"}), 500

if __name__ == '__main__':
    app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.0.100:5000
# Press CTRL+C to quit
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:52:22] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 18:53:10] "POST /fetch-sensor-data HTTP/1.1" 400 -
# 127.0.0.1 - - [06/Apr/2025 18:53:21] "POST /fetch-sensor-data HTTP/1.1" 500 -
# 127.0.0.1 - - [06/Apr/2025 18:54:23] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:54:39] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:55:22] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 18:56:44] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:56:52] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:58:19] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 18:58:27] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 18:58:36] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 18:59:58] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:00:11] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 19:08:29] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:08:51] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:09:14] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 19:12:23] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:12:33] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:13:13] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:18:31] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:20:24] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:21:36] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:21:46] "GET /fetch-sensor-data HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2025 19:25:07] "POST /fetch-sensor-data HTTP/1.1" 201 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:25:18] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:42:40] "GET /fetch-sensor-data HTTP/1.1" 200 -
# C:\Users\adres\AppData\Local\Temp\ipykernel_10936\2299641942.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 127.0.0.1 - - [06/Apr/2025 19:43:04] "GET /fetch-sensor-data HTTP/1.1" 200 -
